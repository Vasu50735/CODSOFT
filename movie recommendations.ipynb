# %%
import pandas as pd
import random

# Sample data for genres, movies, lead role, and ratings
movies_data = {
    'Crime': [
        ('The Godfather', 9.2, 'Marlon Brando', 175), ('Goodfellas', 8.7, 'Ray Liotta', 146), 
        ('The Dark Knight', 9.0, 'Christian Bale', 152), ('Pulp Fiction', 8.9, 'John Travolta', 154),
        ('Scarface', 8.3, 'Al Pacino', 170), ('The Shawshank Redemption', 9.3, 'Tim Robbins', 142), 
        ('Casino', 8.2, 'Robert De Niro', 178), ('The Departed', 8.5, 'Leonardo DiCaprio', 151),
        ('Heat', 8.2, 'Al Pacino', 170), ('Chinatown', 8.2, 'Jack Nicholson', 131),
        ('The Usual Suspects', 8.5, 'Kevin Spacey', 106), ('Donnie Brasco', 8.2, 'Johnny Depp', 127),
        ('The Silence of the Lambs', 8.6, 'Jodie Foster', 118), ('A Clockwork Orange', 8.3, 'Malcolm McDowell', 136),
        ('L.A. Confidential', 8.6, 'Russell Crowe', 138), ('Reservoir Dogs', 8.3, 'Harvey Keitel', 99),
        ('American History X', 8.5, 'Edward Norton', 119), ('Oldboy', 8.4, 'Choi Min-sik', 120),
        ('The Killing', 8.0, 'Sterling Hayden', 85), ('The Untouchables', 7.9, 'Kevin Costner', 119),
        ('Prisoners', 8.1, 'Hugh Jackman', 153), ('Zodiac', 7.7, 'Jake Gyllenhaal', 157),
        ('Insomnia', 7.2, 'Al Pacino', 118), ('Sin City', 8.0, 'Bruce Willis', 124), ('Gomorrah', 7.7, 'Salvatore Esposito', 137)
    ],
    'Thriller': [
        ('Se7en', 8.6, 'Brad Pitt', 127), ('Inception', 8.8, 'Leonardo DiCaprio', 148), 
        ('The Dark Knight', 9.0, 'Christian Bale', 152), ('Fight Club', 8.8, 'Edward Norton', 139),
        ('Shutter Island', 8.2, 'Leonardo DiCaprio', 138), ('Gone Girl', 8.1, 'Ben Affleck', 149), 
        ('The Sixth Sense', 8.1, 'Bruce Willis', 107), ('Memento', 8.4, 'Guy Pearce', 113),
        ('Prisoners', 8.1, 'Hugh Jackman', 153), ('The Prestige', 8.5, 'Christian Bale', 130),
        ('The Game', 7.8, 'Michael Douglas', 129), ('Insomnia', 7.2, 'Al Pacino', 118), 
        ('Black Swan', 8.0, 'Natalie Portman', 108), ('The Machinist', 7.7, 'Christian Bale', 101),
        ('Oldboy', 8.4, 'Choi Min-sik', 120), ('The Invisible Man', 7.1, 'Elisabeth Moss', 124),
        ('Don’t Breathe', 7.1, 'Stephen Lang', 88), ('The Others', 7.6, 'Nicole Kidman', 104),
        ('A Beautiful Mind', 8.2, 'Russell Crowe', 135), ('The Village', 6.5, 'Joaquin Phoenix', 108),
        ('Zodiac', 7.7, 'Jake Gyllenhaal', 157), ('Interstellar', 8.6, 'Matthew McConaughey', 169),
        ('American Psycho', 7.6, 'Christian Bale', 102), ('The Fugitive', 7.8, 'Harrison Ford', 130),
        ('Shutter Island', 8.2, 'Leonardo DiCaprio', 138)
    ],
    'Fantasy': [
        ('The Lord of the Rings: The Return of the King', 8.9, 'Elijah Wood', 201), 
        ('Harry Potter and the Sorcerer\'s Stone', 7.6, 'Daniel Radcliffe', 152),
        ('The Lord of the Rings: The Fellowship of the Ring', 8.8, 'Elijah Wood', 178),
        ('The Hobbit: An Unexpected Journey', 7.8, 'Martin Freeman', 169),
        ('The Chronicles of Narnia: The Lion, the Witch and the Wardrobe', 6.9, 'Georgie Henley', 143),
        ('The Matrix', 8.7, 'Keanu Reeves', 136), ('The Dark Knight', 9.0, 'Christian Bale', 152),
        ('Interstellar', 8.6, 'Matthew McConaughey', 169), ('Alice in Wonderland', 6.4, 'Johnny Depp', 108),
        ('Stardust', 7.7, 'Claire Danes', 127), ('Doctor Strange', 7.5, 'Benedict Cumberbatch', 115),
        ('Avatar', 7.8, 'Sam Worthington', 162), ('Pan\'s Labyrinth', 8.2, 'Ivana Baquero', 118),
        ('King Kong', 7.2, 'Naomi Watts', 187), ('The Wizard of Oz', 8.0, 'Judy Garland', 102),
        ('The NeverEnding Story', 7.4, 'Barret Oliver', 102), ('The Princess Bride', 8.1, 'Cary Elwes', 98),
        ('Shrek', 7.9, 'Mike Myers', 90), ('Coraline', 7.7, 'Dakota Fanning', 100),
        ('Labyrinth', 7.4, 'Jennifer Connelly', 101), ('The Secret Life of Walter Mitty', 7.3, 'Ben Stiller', 114),
        ('The Golden Compass', 6.1, 'Nicole Kidman', 113), ('Percy Jackson & the Olympians: The Lightning Thief', 5.9, 'Logan Lerman', 118),
        ('The Amazing Spider-Man', 6.9, 'Andrew Garfield', 136), ('The Lion King', 8.5, 'Matthew Broderick', 88)
    ],
    'Comedy': [
        ('The Big Lebowski', 8.1, 'Jeff Bridges', 117), ('Superbad', 7.6, 'Jonah Hill', 113),
        ('The Hangover', 7.7, 'Bradley Cooper', 100), ('Dumb and Dumber', 7.3, 'Jim Carrey', 107),
        ('Groundhog Day', 8.0, 'Bill Murray', 101), ('Monty Python and the Holy Grail', 8.2, 'Graham Chapman', 91),
        ('The Grand Budapest Hotel', 8.1, 'Ralph Fiennes', 99), ('Ferris Bueller\'s Day Off', 7.8, 'Matthew Broderick', 103),
        ('Anchorman', 7.2, 'Will Ferrell', 94), ('Step Brothers', 6.9, 'Will Ferrell', 98), 
        ('Shaun of the Dead', 7.9, 'Simon Pegg', 99), ('This Is Spinal Tap', 8.0, 'Michael McKean', 82),
        ('The 40-Year-Old Virgin', 6.9, 'Steve Carell', 116), ('Napoleon Dynamite', 6.9, 'Jon Heder', 96),
        ('Airplane!', 7.7, 'Robert Hays', 88), ('Blazing Saddles', 8.0, 'Cleavon Little', 93),
        ('Some Like It Hot', 8.2, 'Marilyn Monroe', 121), ('Back to the Future', 8.5, 'Michael J. Fox', 116),
        ('The Princess Bride', 8.1, 'Cary Elwes', 98), ('Toy Story', 8.1, 'Tom Hanks', 81), 
        ('Clerks', 7.7, 'Brian O\'Halloran', 92), ('Juno', 7.4, 'Ellen Page', 96),
        ('Hot Fuzz', 7.8, 'Simon Pegg', 121), ('Big Daddy', 6.4, 'Adam Sandler', 93),
        ('The Naked Gun', 7.6, 'Leslie Nielsen', 85)
    ],
    'Adventure': [
        ('Wonder Woman', 7.4, 'Gal Gadot', 141), ('Lara Croft: Tomb Raider', 6.3, 'Angelina Jolie', 100),
        ('The Hunger Games', 7.2, 'Jennifer Lawrence', 142), ('The Lord of the Rings: The Fellowship of the Ring', 8.8, 'Elijah Wood', 178),
        ('Guardians of the Galaxy', 8.0, 'Chris Pratt', 121), ('Indiana Jones and the Last Crusade', 8.2, 'Harrison Ford', 127),
        ('The Mummy', 7.0, 'Brendan Fraser', 124), ('Pirates of the Caribbean: The Curse of the Black Pearl', 8.0, 'Johnny Depp', 143),
        ('The Hunger Games', 7.2, 'Jennifer Lawrence', 142), ('The Lord of the Rings: The Fellowship of the Ring', 8.8, 'Elijah Wood', 178),
        ('Jumanji: Welcome to the Jungle', 6.9, 'Dwayne Johnson', 119), ('Star Wars: The Force Awakens', 7.8, 'Daisy Ridley', 138),
        ('Avatar', 7.8, 'Sam Worthington', 162), ('The Chronicles of Narnia: The Lion, the Witch and the Wardrobe', 6.9, 'Georgie Henley', 143),
        ('Spider-Man: No Way Home', 8.3, 'Tom Holland', 148), ('The Amazing Spider-Man', 6.9, 'Andrew Garfield', 136),
        ('Pirates of the Caribbean: Dead Man\'s Chest', 7.3, 'Johnny Depp', 151), ('Aquaman', 6.9, 'Jason Momoa', 143),
        ('The Dark Knight Rises', 8.4, 'Christian Bale', 164), ('Iron Man', 7.9, 'Robert Downey Jr.', 126),
        ('Thor: Ragnarok', 7.9, 'Chris Hemsworth', 130), ('Doctor Strange', 7.5, 'Benedict Cumberbatch', 115),
        ('The Incredibles', 8.0, 'Craig T. Nelson', 115), ('Shazam!', 7.0, 'Asher Angel', 132), ('Batman Begins', 8.3, 'Christian Bale', 140),
        ('Transformers', 7.0, 'Shia LaBeouf', 144), ('Frozen', 7.4, 'Idina Menzel', 102)
    ]
}

# Function to display top IMDb rated movies
def display_top_rated_movies():
    top_rated_movies = [
        ('The Shawshank Redemption', 9.3), ('The Godfather', 9.2), 
        ('The Dark Knight', 9.0), ('Pulp Fiction', 8.9), 
        ('The Lord of the Rings: The Return of the King', 8.9), ('Forrest Gump', 8.8), 
        ('Inception', 8.8), ('The Matrix', 8.7), 
        ('Goodfellas', 8.7), ('Fight Club', 8.8),
        ('The Lord of the Rings: The Fellowship of the Ring', 8.8), 
        ('The Empire Strikes Back', 8.7), ('The Lion King', 8.5), 
        ('The Silence of the Lambs', 8.6), ('Schindler\'s List', 8.9),
        ('Interstellar', 8.6), ('The Prestige', 8.5),
        ('The Departed', 8.5), ('The Green Mile', 8.6),
        ('Gladiator', 8.5), ('The Usual Suspects', 8.5),
        ('The Shining', 8.4), ('Star Wars: A New Hope', 8.6),
        ('Back to the Future', 8.5), ('The Dark Knight Rises', 8.4)
    ]
    print("\nTop 25 IMDb Rated Movies:")
    print(f"{'Title':<40} {'Rating'}")
    print("-" * 50)
    for movie, rating in top_rated_movies[:25]:
        print(f"{movie:<40} {rating}")
    print()

# Function to display movies based on genre
def display_movies_by_genre(genre):
    print(f"\nTop Movies in {genre} Genre:")
    print(f"{'Title':<40} {'IMDb Rating'} {'Lead Role':<20} {'Runtime (min)'}")
    print("-" * 70)
    for movie, rating, lead_role, runtime in movies_data.get(genre, [])[:25]:  # Limit to 25 movies
        print(f"{movie:<40} {rating:<6} {lead_role:<20} {runtime}")
    print()

# Main Menu
while True:
    print("\nWhat would you like to do?")
    print("1. See top 25 IMDb rated movies")
    print("2. Choose a genre and see top movies")

    choice = input("Choose an option (1/2): ")

    if choice == '1':
        display_top_rated_movies()
    elif choice == '2':
        print("\nAvailable Genres:")
        print("1. Crime")
        print("2. Thriller")
        print("3. Fantasy")
        print("4. Comedy")
        print("5. Adventure")
        
        genre_choice = input("Select a genre (1-5): ")

        if genre_choice == '1':
            genre = 'Crime'
        elif genre_choice == '2':
            genre = 'Thriller'
        elif genre_choice == '3':
            genre = 'Fantasy'
        elif genre_choice == '4':
            genre = 'Comedy'
        elif genre_choice == '5':
            genre = 'Adventure'
        else:
            print("Invalid choice. Please try again.")
            continue
        
        display_movies_by_genre(genre)
    else:
        print("Invalid choice. Please select '1' or '2'.")
# Out:
# What would you like to do?
# 1. See top 25 IMDb rated movies
# 2. Choose a genre and see top movies
# Choose an option (1/2):  1
# Top 25 IMDb Rated Movies:
# Title                                    Rating
# --------------------------------------------------
# The Shawshank Redemption                 9.3
# The Godfather                            9.2
# The Dark Knight                          9.0
# Pulp Fiction                             8.9
# The Lord of the Rings: The Return of the King 8.9
# Forrest Gump                             8.8
# Inception                                8.8
# The Matrix                               8.7
# Goodfellas                               8.7
# Fight Club                               8.8
# The Lord of the Rings: The Fellowship of the Ring 8.8
# The Empire Strikes Back                  8.7
# The Lion King                            8.5
# The Silence of the Lambs                 8.6
# Schindler's List                         8.9
# ...
